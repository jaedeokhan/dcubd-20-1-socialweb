# %%
import pandas as pd
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %% [markdown]
# https://www.it-swarm.dev/ko/python/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%97%90%EC%84%9C-%EC%9C%A0%EB%8B%88-%EC%BD%94%EB%93%9C-utf8-%ED%8C%8C%EC%9D%BC-%EC%9D%BD%EA%B8%B0-%EB%B0%8F-%EC%93%B0%EA%B8%B0/958177245/ => open function

# %%
f = open("C:/Users/330-15/Desktop/20_1_computer/SocialWebMining/txt/트럼프취임연설문.txt", mode='r',
           encoding='utf-8')
lines = f.readlines()[0]
f.close()

# %%
lines[0:100]
# Out:
# 'Chief Justice Roberts, President Carter, President Clinton, President Bush, President Obama, fellow '

# %%
tokenizer = RegexpTokenizer('[\w]+')
stop_words = stopwords.words('english')
words = lines.lower()
tokens = tokenizer.tokenize(words)
stopped_token = [i for i in list((tokens)) if not i in stop_words]
stopped_token2 = [i for i in stopped_token if len(i) > 1]

# %%
pd.Series(stopped_token2).value_counts().head(10)
# Out:
# america     20
# american    11
# people      10
# country      9
# one          8
# every        7
# nation       7
# great        6
# back         6
# world        6
# dtype: int64

# %%
import os
java_home = os.environ.get('JAVA_HOME', None)
if not java_home:
    java_path ="C:\Program Files\Java\jdk1.8.0_191/bin"
    os.environ['JAVA_HOME'] = java_path
else:
    print (java_home)
# Out:
# C:\Program Files\Java\jdk1.8.0_191

# %%
import pandas as pd
from konlpy.tag import Hannanum

hannanum = Hannanum()

f = open('C:/Users/330-15/Desktop/20_1_computer/SocialWebMining/txt/문재인대통령취임연설문.txt', 
         mode='r',
         encoding='utf-8')
lines = f.readlines()
f.close()

temp = []
for i in range(len(lines)):
    temp.append(hannanum.nouns(lines[i]))

def flatten(l):
    flatList = []
    for elem in l:
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.apped(elem)
    return flatList

word_list = flatten(temp)
word_list = pd.Series([x for x in word_list if len(x) > 1])
word_list.value_counts().head(10)
# Out:
# 대통령     29
# 국민      19
# 대한민국     9
# 우리       8
# 여러분      7
# 역사       6
# 국민들      6
# 나라       6
# 대통령의     5
# 세상       5
# dtype: int64

# %%
from wordcloud import WordCloud
from collections import Counter

font_path = "C:/Windows/Fonts/malgun.ttf"

wordcloud = WordCloud(
    font_path = font_path,
    width = 800,
    height = 800,
    background_color="white"
)

# %%
count = Counter(stopped_token2)
wordcloud = wordcloud.generate_from_frequencies(count)

# %%
array = wordcloud.to_array()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()
fig.savefig('wordcloud.png')

# %%
count = Counter(word_list)
wordcloud = wordcloud.generate_from_frequencies(count)
array = wordcloud.to_array()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()
fig.savefig('wordcloud.png')
